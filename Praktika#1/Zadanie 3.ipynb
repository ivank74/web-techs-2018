# %% [markdown]
# # Задание 3
# Для выполнения задания использовал Postman. В задании нужно отправить запросы на http://httpbin.org, проанализировать ответ и код состояния. Описать работу HTTP протокола в каждом запросе.

# %% [markdown]
# # /ip
# Status: 200 OK
#
# Body
# {"origin": "5.189.57.149"}
#
# Headers
#
# Access-Control-Allow-Credentials →true
# Access-Control-Allow-Origin →*
# Connection →keep-alive
# Content-Length →31
# Content-Type →application/json
# Date →Fri, 05 Oct 2018 18:43:28 GMT
# Server →gunicorn/19.9.0
# Via →1.1 vegur

# %% [markdown]
# # /get
# Status: 200 OK
#
# body
# {
#     "args": {
#         "1": "2",
#         "2/0": "",
#         "error": "True HTTP/1.1",
#         "foo": "bar"
#     },
#     "headers": {
#         "Accept": "*/*",
#         "Accept-Encoding": "gzip, deflate",
#         "Cache-Control": "no-cache",
#         "Connection": "close",
#         "Host": "httpbin.org",
#         "Postman-Token": "88709831-3f16-44ab-b5d6-185657f93707",
#         "User-Agent": "PostmanRuntime/7.3.0"
#     },
#     "origin": "5.189.57.149",
#     "url": "http://httpbin.org/get?foo=bar&1=2&2%2F0&error=True HTTP%2F1.1"
# }
#
# Headers
# Access-Control-Allow-Credentials →true
# Access-Control-Allow-Origin →*
# Connection →keep-alive
# Content-Length →481
# Content-Type →application/json
# Date →Fri, 05 Oct 2018 19:06:52 GMT
# Server →gunicorn/19.9.0
# Via →1.1 vegur

# %% [markdown]
# # /post
# Status: 200 OK
# body
# {
#     "args": {},
#     "data": "",
#     "files": {},
#     "form": {},
#     "headers": {
#         "Accept": "*/*",
#         "Accept-Encoding": "gzip, deflate",
#         "Cache-Control": "no-cache",
#         "Connection": "close",
#         "Content-Length": "0",
#         "Content-Type": "application/x-www-form-urlencoded",
#         "Cookie": "country=\"Ru HTTP/1.1\"",
#         "Host": "httpbin.org",
#         "Postman-Token": "7730f49d-6843-4044-9286-015ec79c00bf",
#         "User-Agent": "PostmanRuntime/7.3.0"
#     },
#     "json": null,
#     "origin": "5.189.57.149",
#     "url": "http://httpbin.org/post"
# }
#
# Headers
# Access-Control-Allow-Credentials →true
# Access-Control-Allow-Origin →*
# Connection →keep-alive
# Content-Length →551
# Content-Type →application/json
# Date →Fri, 05 Oct 2018 20:10:54 GMT
# Server →gunicorn/19.9.0
# Via →1.1 vegur

# %% [markdown]
# # /cookies/set
#
# Status: 200 OK
#
# body
# {
#     "cookies": {
#         "country": "Ru HTTP/1.1"
#     }
# }
# Headers
# Access-Control-Allow-Credentials →true
# Access-Control-Allow-Origin →*
# Connection →keep-alive
# Content-Length →52
# Content-Type →application/json
# Date →Fri, 05 Oct 2018 19:19:04 GMT
# Server →gunicorn/19.9.0
# Via →1.1 vegur

# %% [markdown]
# # /cookies
#
# Status: 200 OK
#
# body
# {
#     "cookies": {
#         "country": "Ru HTTP/1.1"
#     }
# }
# Headers
# Access-Control-Allow-Credentials →true
# Access-Control-Allow-Origin →*
# Connection →keep-alive
# Content-Length →52
# Content-Type →application/json
# Date →Fri, 05 Oct 2018 20:13:57 GMT
# Server →gunicorn/19.9.0
# Via →1.1 vegur

# %% [markdown]
# # /redirect
# Status: 200 OK
#
# body
# { "args": {},
# "headers":
# { "Accept": "/",
# "Accept-Encoding": "gzip, deflate",
# "Accept-Language": "ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7",
# "Cache-Control": "no-cache",
# "Connection": "close", "Cookie": "country=Ru",
# "Host": "httpbin.org",
# "Postman-Token": "51676ae1-99cd-8e83-e941-4f4eecb7aabe",
# "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36" }, "origin": "5.189.57.149", "url": "http://httpbin.org/get" }
# Headers
# Access-Control-Allow-Credentials →true
# Access-Control-Allow-Origin →*
# Connection →keep-alive
# Content-Length →233
# Content-Type →text/html
# Date →Fri, 05 Oct 2018 20:16:43 GMT
# Server →gunicorn/19.9.0
# Via →1.1 vegur
